# %% [markdown]
# **Image Denoising using NLM (Non-Local Means) Algorithm**

# %%
import cv2
import numpy as np
from skimage import io, img_as_float
from skimage.restoration import denoise_nl_means, estimate_sigma

# %%
from matplotlib import pyplot

# %%
img = img_as_float(io.imread('/content/drive/MyDrive/GAN/FINAL_IMAGES_0.4/Mine1_e001.jpg'))

# %%
sigma_est = np.mean(estimate_sigma(img, multichannel=True))
# Out:
# <ipython-input-5-456c75eb069e>:1: FutureWarning: `multichannel` is a deprecated argument name for `estimate_sigma`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   sigma_est = np.mean(estimate_sigma(img, multichannel=True))

# %%
denoised_img_h_1 = denoise_nl_means(img, h=1.*sigma_est,fast_mode=True,
                                patch_size=5, patch_distance=3,
                                multichannel=True)
# Out:
# <ipython-input-19-0ca064377988>:1: FutureWarning: `multichannel` is a deprecated argument name for `denoise_nl_means`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   denoised_img_h_1 = denoise_nl_means(img, h=1.*sigma_est,fast_mode=True,

# %%
pyplot.imshow(img)

# %%
pyplot.imshow(denoised_img_h_1)

# %%
denoised_img_h_1_25 = denoise_nl_means(img, h=1.25*sigma_est,fast_mode=True,
                                patch_size=5, patch_distance=3,
                                multichannel=True)
# Out:
# <ipython-input-22-74be3f231cde>:1: FutureWarning: `multichannel` is a deprecated argument name for `denoise_nl_means`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   denoised_img_h_1_25 = denoise_nl_means(img, h=1.25*sigma_est,fast_mode=True,

# %%
pyplot.imshow(denoised_img_h_1_25)

# %%
denoised_img_h_1_5 = denoise_nl_means(img, h=1.5*sigma_est,fast_mode=True,
                                patch_size=5, patch_distance=3,
                                multichannel=True)
pyplot.imshow(denoised_img_h_1_5)
# Out:
# <ipython-input-29-6e5c35ff7c1d>:1: FutureWarning: `multichannel` is a deprecated argument name for `denoise_nl_means`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   denoised_img_h_1_5 = denoise_nl_means(img, h=1.5*sigma_est,fast_mode=True,

# %%
denoised_img_h_1_8 = denoise_nl_means(img, h=1.8*sigma_est,fast_mode=True,
                                patch_size=5, patch_distance=3,
                                multichannel=True)
pyplot.imshow(denoised_img_h_1_8)
# Out:
# <ipython-input-25-46a013782e84>:1: FutureWarning: `multichannel` is a deprecated argument name for `denoise_nl_means`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   denoised_img_h_1_8 = denoise_nl_means(img, h=1.8*sigma_est,fast_mode=True,

# %%
denoised_img_h_3 = denoise_nl_means(img, h=3*sigma_est,fast_mode=True,
                                patch_size=5, patch_distance=3,
                                multichannel=True)
pyplot.imshow(denoised_img_h_3)
# Out:
# <ipython-input-26-590df3ffa431>:1: FutureWarning: `multichannel` is a deprecated argument name for `denoise_nl_means`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   denoised_img_h_3 = denoise_nl_means(img, h=3*sigma_est,fast_mode=True,

# %%
denoised_img_h_100 = denoise_nl_means(img, h=100*sigma_est,fast_mode=True,
                                patch_size=5, patch_distance=3,
                                multichannel=True)
pyplot.imshow(denoised_img_h_100)
# Out:
# <ipython-input-27-214d1094f577>:1: FutureWarning: `multichannel` is a deprecated argument name for `denoise_nl_means`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   denoised_img_h_100 = denoise_nl_means(img, h=100*sigma_est,fast_mode=True,
